# %%
import pymongo
conn = pymongo.MongoClient('mongodb://cmmuser:cmm#secret123@localhost:27017/cmm')

# %%
conn.the_database.authenticate("cmmuser", "cmm#secret123", source="cmm")
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-9-3ef77c2f4d4a> in <module>
# ----> 1 conn.the_database.authenticate("cmmuser", "cmm#secret123", source="cmm")
#
# ~/.local/lib/python3.7/site-packages/pymongo/database.py in authenticate(self, name, password, source, mechanism, **kwargs)
#    1344             self.name,
#    1345             credentials,
# -> 1346             connect=True)
#    1347
#    1348         return True
#
# ~/.local/lib/python3.7/site-packages/pymongo/mongo_client.py in _cache_credentials(self, source, credentials, connect)
#     644             # get_socket() logs out of the database if logged in with old
#     645             # credentials, and logs in with new ones.
# --> 646             with server.get_socket(all_credentials) as sock_info:
#     647                 sock_info.authenticate(credentials)
#     648
#
# ...

# %%
conn.list_database_names()
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-2-6dc220ce6d0a> in <module>
# ----> 1 conn.list_database_names()
#
# ~/.local/lib/python3.7/site-packages/pymongo/mongo_client.py in list_database_names(self, session)
#    1697         """
#    1698         return [doc["name"]
# -> 1699                 for doc in self.list_databases(session, nameOnly=True)]
#    1700
#    1701     def database_names(self, session=None):
#
# ~/.local/lib/python3.7/site-packages/pymongo/mongo_client.py in list_databases(self, session, **kwargs)
#    1678         cmd.update(kwargs)
#    1679         admin = self._database_default_options("admin")
# -> 1680         res = admin.command(cmd, session=session)
#    1681         # listDatabases doesn't return a cursor (yet). Fake one.
#    1682         cursor = {
#
# ...

# %%
MFLIX_DB_URI = "mongodb+srv://mflixAppUser:mflixAppPwd@hertz-gsbvl.mongodb.net/test"
MFLIX_DB_NAME = "sample_mflix"

# %%
MFLIX_DB_URI = "mongodb://cmmuser:cmm#secret123@localhost:27017/cmm"
MFLIX_DB_NAME = "cmm"

# %%
MFLIX_DB_URI = "mongodb+srv://mflixAppUser:mflixAppPwd@hertz-gsbvl.mongodb.net/test"
MFLIX_DB_NAME = "sample_mflix"
db = pymongo.MongoClient(
MFLIX_DB_URI,
maxPoolSize=50,
wtimeout=2500,
)[MFLIX_DB_NAME]

db.list_collection_names()

# %%
db.the_database.authenticate("cmmuser", "cmm#secret123", source="cmm")
# Out:
# True

# %%
# use admin
# db.createUser(
#   {
#     user: "cmmadmin",
#     pwd: "cmm@secret123",
#     roles: [ { role: "userAdminAnyDatabase", db: "cmm" } ]
#   }
# )

# %%
MFLIX_DB_URI = "mongodb://myUserAdmin:admin123@localhost:27017/"

# %%
conn = pymongo.MongoClient(MFLIX_DB_URI)

# %%
db = conn['cmm']

# %%
db.list_collection_names()
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-40-cf3ed68fcf38> in <module>
# ----> 1 db.list_collection_names()
#
# ~/.local/lib/python3.7/site-packages/pymongo/database.py in list_collection_names(self, session, filter, **kwargs)
#     760
#     761         return [result["name"]
# --> 762                 for result in self.list_collections(session=session, **kwargs)]
#     763
#     764     def collection_names(self, include_system_collections=True,
#
# ~/.local/lib/python3.7/site-packages/pymongo/database.py in list_collections(self, session, filter, **kwargs)
#     720                      or ReadPreference.PRIMARY)
#     721         with self.__client._socket_for_reads(
# --> 722                 read_pref) as (sock_info, slave_okay):
#     723             return self._list_collections(
# ...

# %%
use cmm
db.createUser(
  {
    user: "cmmuser",
    pwd: "cmm#secret123",
    roles: [ { role: "readWrite", db: "cmm" },
             { role: "read", db: "cmm" } ]
  }
)
